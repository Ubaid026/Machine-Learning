# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("car dekho data.csv")
df
# Out:
#     Car_Name        company  Year  Selling_Price  Present_Price  Kms_Driven  \
# 0       ritz  maruti suzuki  2014           3.35           5.59       27000
# 1        sx4  maruti suzuki  2013           4.75           9.54       43000
# 2       ciaz  maruti suzuki  2017           7.25           9.85        6900
# 3    wagon r  maruti suzuki  2011           2.85           4.15        5200
# 4      swift  maruti suzuki  2014           4.60           6.87       42450
# ..       ...            ...   ...            ...            ...         ...
# 296     city          honda  2016           9.50          11.60       33988
# 297     brio          honda  2015           4.00           5.90       60000
# 298     city          honda  2009           3.35          11.00       87934
# 299     city          honda  2017          11.50          12.50        9000
# 300     brio          honda  2016           5.30           5.90        5464
#
#     Fuel_Type Seller_Type Transmission  Owner
# ...

# %%
df.shape
# Out:
# (301, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   company        301 non-null    object
#  2   Year           301 non-null    int64
#  3   Selling_Price  301 non-null    float64
#  4   Present_Price  301 non-null    float64
#  5   Kms_Driven     301 non-null    int64
#  6   Fuel_Type      301 non-null    object
#  7   Seller_Type    301 non-null    object
#  8   Transmission   301 non-null    object
#  9   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(5)
# memory usage: 23.6+ KB

# %%
df.isna().sum()
# Out:
# Car_Name         0
# company          0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
df.apply(lambda x:x.nunique())
# Out:
# Car_Name          98
# company            9
# Year              16
# Selling_Price    156
# Present_Price    147
# Kms_Driven       206
# Fuel_Type          3
# Seller_Type        2
# Transmission       2
# Owner              3
# dtype: int64

# %%
-df["Car_Name"].value_counts()
# Out:
# city                       -26
# corolla altis              -16
# verna                      -14
# fortuner                   -11
# brio                       -10
#                             ..
# Honda CB Trigger            -1
# Yamaha FZ S                 -1
# Bajaj Pulsar 135 LS         -1
# Activa 4g                   -1
# Bajaj Avenger Street 220    -1
# Name: Car_Name, Length: 98, dtype: int64

# %%
df[df["Car_Name"]=="city"]
# Out:
#     Car_Name company  Year  Selling_Price  Present_Price  Kms_Driven  \
# 251     city   honda  2013           5.00           9.90       56701
# 253     city   honda  2014           7.20           9.90       48000
# 254     city   honda  2013           5.25           9.90       54242
# 256     city   honda  2016          10.25          13.60       49562
# 257     city   honda  2015           8.50          13.60       40324
# 258     city   honda  2015           8.40          13.60       25000
# 260     city   honda  2016           9.15          13.60       29223
# 267     city   honda  2016           8.35           9.40       19434
# 269     city   honda  2015           6.70          10.00       18828
# 270     city   honda  2011           4.10          10.00       69341
# 271     city   honda  2009           3.00          10.00       69562
# 272     city   honda  2015           7.50          10.00       27600
# 275     city   honda  2016          10.90          13.60       30753
# ...

# %%
df["company"].value_counts()
# Out:
# honda            70
# maruti suzuki    50
# hyndai           50
# other            39
# toyota           36
# bajaj            25
# hero             15
# yamaha            8
# tvs               8
# Name: company, dtype: int64

# %%
df["Selling_Price"].agg(["min","max"])
# Out:
# min     0.1
# max    35.0
# Name: Selling_Price, dtype: float64

# %%
df[df["Selling_Price"]==35.0]
# Out:
#         Car_Name company  Year  Selling_Price  Present_Price  Kms_Driven  \
# 86  land cruiser   other  2010           35.0           92.6       78000
#
#    Fuel_Type Seller_Type Transmission  Owner
# 86    Diesel      Dealer       Manual      0

# %%
df[df["Selling_Price"]==0.1]
# Out:
#              Car_Name company  Year  Selling_Price  Present_Price  Kms_Driven  \
# 200  Bajaj Pulsar 150   bajaj  2006            0.1           0.75       92233
#
#     Fuel_Type Seller_Type Transmission  Owner
# 200    Petrol  Individual       Manual      0

# %%
df["Present_Price"].agg(["min","max"])
# Out:
# min     0.32
# max    92.60
# Name: Present_Price, dtype: float64

# %%
df[df["Present_Price"]==0.32]
# Out:
#           Car_Name company  Year  Selling_Price  Present_Price  Kms_Driven  \
# 195  Bajaj  ct 100   bajaj  2015           0.18           0.32       35000
#
#     Fuel_Type Seller_Type Transmission  Owner
# 195    Petrol  Individual       Manual      0

# %%
df.drop(columns=["Car_Name","company"],inplace=True)

# %%
df["Current_year"]=2022

# %%
df
# Out:
#      Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0    2014           3.35           5.59       27000    Petrol      Dealer
# 1    2013           4.75           9.54       43000    Diesel      Dealer
# 2    2017           7.25           9.85        6900    Petrol      Dealer
# 3    2011           2.85           4.15        5200    Petrol      Dealer
# 4    2014           4.60           6.87       42450    Diesel      Dealer
# ..    ...            ...            ...         ...       ...         ...
# 296  2016           9.50          11.60       33988    Diesel      Dealer
# 297  2015           4.00           5.90       60000    Petrol      Dealer
# 298  2009           3.35          11.00       87934    Petrol      Dealer
# 299  2017          11.50          12.50        9000    Diesel      Dealer
# 300  2016           5.30           5.90        5464    Petrol      Dealer
#
#     Transmission  Owner  Current_year
# 0         Manual      0          2022
# ...

# %%
df["No.of_years"]=df["Current_year"]-df["Year"]

# %%
df.drop(columns=["Year","Current_year"],inplace=True)

# %%
df
# Out:
#      Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0             3.35           5.59       27000    Petrol      Dealer
# 1             4.75           9.54       43000    Diesel      Dealer
# 2             7.25           9.85        6900    Petrol      Dealer
# 3             2.85           4.15        5200    Petrol      Dealer
# 4             4.60           6.87       42450    Diesel      Dealer
# ..             ...            ...         ...       ...         ...
# 296           9.50          11.60       33988    Diesel      Dealer
# 297           4.00           5.90       60000    Petrol      Dealer
# 298           3.35          11.00       87934    Petrol      Dealer
# 299          11.50          12.50        9000    Diesel      Dealer
# 300           5.30           5.90        5464    Petrol      Dealer
#
#     Transmission  Owner  No.of_years
# 0         Manual      0            8
# 1         Manual      0            9
# ...

# %%
df=pd.get_dummies(df,drop_first=True)

# %%
df
# Out:
#      Selling_Price  Present_Price  Kms_Driven  Owner  No.of_years  \
# 0             3.35           5.59       27000      0            8
# 1             4.75           9.54       43000      0            9
# 2             7.25           9.85        6900      0            5
# 3             2.85           4.15        5200      0           11
# 4             4.60           6.87       42450      0            8
# ..             ...            ...         ...    ...          ...
# 296           9.50          11.60       33988      0            6
# 297           4.00           5.90       60000      0            7
# 298           3.35          11.00       87934      0           13
# 299          11.50          12.50        9000      0            5
# 300           5.30           5.90        5464      0            6
#
#      Fuel_Type_Diesel  Fuel_Type_Petrol  Seller_Type_Individual  \
# 0                   0                 1                       0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Selling_Price           301 non-null    float64
#  1   Present_Price           301 non-null    float64
#  2   Kms_Driven              301 non-null    int64
#  3   Owner                   301 non-null    int64
#  4   No.of_years             301 non-null    int64
#  5   Fuel_Type_Diesel        301 non-null    uint8
#  6   Fuel_Type_Petrol        301 non-null    uint8
#  7   Seller_Type_Individual  301 non-null    uint8
#  8   Transmission_Manual     301 non-null    uint8
# dtypes: float64(2), int64(3), uint8(4)
# memory usage: 13.1 KB

# %%
df["Selling_Price"]=df["Selling_Price"].astype("int")

# %%
df["Present_Price"]=df["Present_Price"].astype("int")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Selling_Price           301 non-null    int32
#  1   Present_Price           301 non-null    int32
#  2   Kms_Driven              301 non-null    int64
#  3   Owner                   301 non-null    int64
#  4   No.of_years             301 non-null    int64
#  5   Fuel_Type_Diesel        301 non-null    uint8
#  6   Fuel_Type_Petrol        301 non-null    uint8
#  7   Seller_Type_Individual  301 non-null    uint8
#  8   Transmission_Manual     301 non-null    uint8
# dtypes: int32(2), int64(3), uint8(4)
# memory usage: 10.7 KB

# %%
df.corr()
# Out:
#                         Selling_Price  Present_Price  Kms_Driven     Owner  \
# Selling_Price                1.000000       0.877518    0.032597 -0.083877
# Present_Price                0.877518       1.000000    0.206896  0.007089
# Kms_Driven                   0.032597       0.206896    1.000000  0.089216
# Owner                       -0.083877       0.007089    0.089216  1.000000
# No.of_years                 -0.229302       0.049269    0.524342  0.182104
# Fuel_Type_Diesel             0.547371       0.472090    0.172515 -0.053469
# Fuel_Type_Petrol            -0.535179      -0.464390   -0.172874  0.055687
# Seller_Type_Individual      -0.542332      -0.515092   -0.101419  0.124269
# Transmission_Manual         -0.367935      -0.349275   -0.162510 -0.050316
#
#                         No.of_years  Fuel_Type_Diesel  Fuel_Type_Petrol  \
# Selling_Price             -0.229302          0.547371         -0.535179
# Present_Price              0.049269          0.472090         -0.464390
# ...

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
x=df.drop(columns=["Selling_Price"])
y=df["Selling_Price"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.10,random_state=123)

# %%
x_train.shape
# Out:
# (270, 8)

# %%
y_train.shape
# Out:
# (270,)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test)

# %%
from sklearn.metrics import r2_score,mean_absolute_error,mean_absolute_percentage_error,mean_squared_error

# %%
r2_score(y_test,y_pred)
# Out:
# 0.84011769715173

# %%
mae=mean_absolute_error(y_test,y_pred)
mae
# Out:
# 1.392849090461023

# %%
plt.scatter(x_test.iloc[:,0],y_test)
sns.regplot(x_test.iloc[:,0],y_pred,color = "red",ci = False)
plt.xticks()

plt.yticks()
plt.show();
# Out:
# C:\Users\dell\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
